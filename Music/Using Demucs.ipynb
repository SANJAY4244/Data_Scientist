# %%
! pip install -q demucs !
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# !pip install torchcodec
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 53.4 MB/s eta 0:00:00
# ...

# %%
# !demucs --two-stems=vocals "Kaattrae En Vaasal.mp3"
# Out:
# Important: the default model was recently changed to `htdemucs` the latest Hybrid Transformer Demucs model. In some cases, this model can actually perform worse than previous models. To get back the old default model use `-n mdx_extra_q`.
# Selected model is a bag of 1 models. You will see that many progress bars per track.
# Separated tracks will be stored in /content/separated/htdemucs
# Separating track Kaattrae En Vaasal.mp3
# 100%|██████████████████████████████████████████████████████████████████████| 380.25/380.25 [13:44<00:00,  2.17s/seconds]
# /usr/local/lib/python3.12/dist-packages/torchaudio/__init__.py:178: UserWarning: The 'encoding' parameter is not fully supported by TorchCodec AudioEncoder.
#   return save_with_torchcodec(
# /usr/local/lib/python3.12/dist-packages/torchaudio/__init__.py:178: UserWarning: The 'bits_per_sample' parameter is not directly supported by TorchCodec AudioEncoder.
#   return save_with_torchcodec(

# %%
from google.colab import files

files.download("/content/separated/htdemucs/Unnodu_Vaazhatha_K_S_Chitra/no_vocals.wav")
files.download("/content/separated/htdemucs/Unnodu_Vaazhatha_K_S_Chitra/vocals.wav")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-211043129.py in <cell line: 0>()
#       1 from google.colab import files
#       2
# ----> 3 files.download("/content/separated/htdemucs/Unnodu_Vaazhatha_K_S_Chitra/no_vocals.wav")
#       4 files.download("/content/separated/htdemucs/Unnodu_Vaazhatha_K_S_Chitra/vocals.wav")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/separated/htdemucs/Unnodu_Vaazhatha_K_S_Chitra/no_vocals.wav

# %% [markdown]
# ✅ Task 1: Remix Task
#
# Take:
#
# Vocals from Song A
#
# Music from Song B
#
# Mix and create a new song.
#
# ✅ Task 2: Noise Removal Task
#
# Take an audio with background noise.
#
# Remove noise using separation techniques.
#
# Compare before and after.
